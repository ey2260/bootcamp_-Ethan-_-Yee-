# %%
# This program is attempting to solve the issue of a lack of readily avaialble information regarding correlation between a set of stocks. The goal is to create a simple program that uses historical data to determine this correlation and return this data to the user, al
